# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PATH ='./drive/MyDrive/Dane/PAD_03_PD.csv'

# %% [markdown]
# Zadanie 1 i 2

# %%
import pandas as pd
sf_sal = pd.read_csv(PATH, sep=';')
sf_sal["owned_goods"] = sf_sal["owns_car"] + sf_sal["owns_TV"] + sf_sal["owns_house"] + sf_sal["owns_Phone"]
sf_sal
# Out:
#       ID Country  owns_car  owns_TV  owns_house  owns_Phone gender  Age  \
# 0      1       A       0.0      0.0         0.0           1      M   61
# 1      2       B       0.0      0.0         0.0           1      M   44
# 2      3       A       0.0      0.0         0.0           1      M   56
# 3      4       A       0.0      0.0         0.0           1      M   53
# 4      5       C       1.0      1.0         0.0           1      K   60
# ..   ...     ...       ...      ...         ...         ...    ...  ...
# 795  796       B       0.0      0.0         0.0           1      K   28
# 796  797       B       0.0      0.0         0.0           1      M   26
# 797  798       A       0.0      0.0         0.0           1      M   61
# 798  799       B       0.0      1.0         0.0           1      K   47
# 799  800       B       0.0      1.0         0.0           1      K   51
#
#      owned_goods
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# ...

# %% [markdown]
# Zadanie 1

# %%
by_state = sf_sal.groupby("Country")["ID"].count()
print(by_state)
# Out:
# Country
# A    328
# B    201
# C    186
# D     78
# Name: ID, dtype: int64

# %% [markdown]
# Zadanie 3

# %%
by_gender = sf_sal.groupby("gender")["owned_goods"].mean().round(2)
print(by_gender)
# Out:
# gender
# K    2.80
# M    0.89
# Name: owned_goods, dtype: float64

# %% [markdown]
# Zadanie 4

# %%
df = pd.DataFrame(sf_sal).groupby("Country").agg({'owned_goods' : ['mean'], 'Age' : 'min'}).round(2)
df
# Out:
#         owned_goods Age
#                mean min
# Country
# A              0.86  18
# B              1.46  18
# C              3.03  18
# D              4.00  18
